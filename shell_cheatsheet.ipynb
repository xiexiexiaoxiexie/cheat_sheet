# %%
\enter #换行
mkdir -p #多层
mv name1 name2#重命名
mv name1 name2 dir3 #mv多个文件，最后一个为目录
head -n 10 name#查看前10行
less name1#查看文件，/可搜索字符串
touch name1#创建文件
which -a python #寻找所有的指令目录
locate name#搜索文件名
gzip #压缩
ctrl+z 暂停process，jobs+kill
#等号两边不能接空格
#双引号内的特殊字符如 $ 等， 可以保有原本的特性
#单引号内的特殊字符则仅为一般字符
#version=$（ uname -r）
# $（指令）
#“PATH="$PATH":/home/bin”或“PATH=${PATH}:/home/bin”
# 因为子程序仅会继承父程序的环境变量， 子程序不会继承父程序的自订变量啦！ 父程序的自订变量是无法在子程序内使用的。 但是通过 export 将变量变成环境变量后， 就能够在子程序下面应用了
#grep区分大小写，-i忽略字符大小写的差别
 history -w #强制立刻写入bash_history
!66 #执行history第 66 条指令
source #读入环境配置文件的指令
#source 对 script 的执行会在父程序中执行,其他方法bash 在子程序中执行
* #代表“ 0 个到无穷多个”任意字符
? #代表“一定有一个”任意字符
[ ] #同样代表“一定有一个在括号内”的字符（ 非任意字符） 。 例如 [abcd] 代表“一定有一
个字符， 可能是 a, b, c, d 这四个任何一个
; #连续指令下达分隔符号
（ ） #在中间为子 shell 的起始与结束
#9 SIGKILL 代表强制中断一个程序的进行

# %%
#?： （ 关于上个执行指令的回传值）
echo $?
#变量类型默认为“字串”， 所以若不指定变量类型， 则 1+2 为一个“字串”而不是“计算式”
#
#####array
var[1]="small min"
var[2]="big min"
echo "${var[1]}, ${var[2]}, ${var[3]}"

# %%
#要读取来自键盘输入的变量， 就是用 read 这个指令
stdout #代码是 1 而 stderr 代码是 2
1> #以覆盖的方法将“正确的数据”输出到指定的文件或设备上；
2>#以覆盖的方法将“错误的数据”输出到指定的文件或设备上；
cmd ; cmd #（ 不考虑指令相关性的连续指令下达）
cp file1 file2 &#表示将 file1 这个文件复制为 file2 ， 且放置于背景中执行， 也就是说执行这一个命令之后， 在这一个终端接口仍然可以做其他的工作
cmd1 && cmd2#若 cmd1 执行完毕且正确执行（ $?=0） ， 则开始执行 cmd2。 2. 若 cmd1执行完毕且为错误 （ $?≠0） ， 则 cmd2 不执行。
cmd1 || cmd2#若 cmd1 执行完毕且正确执行（ $?=0） ， 则 cmd2 不执行。 2. 若 cmd1 执行完毕且为错误 （ $?≠0） ， 则开始执行 cmd2。
#在每个管线后面接的第一个数据必定是“指令”喔！ 而且这个指令必须要能够接受 standardinput 的数据才行，
tee#双重重定向
#stdin 与stdout 可以利用减号 "-" 来替代

# %%
#!/bin/bash
...
#可以利用“ $（ （ 计算式） ） ”来进行数值运算的
/path/to/scriptname opt1 opt2 opt3 opt4
$0 $1 $2 $3 $4
test -e filename #该“文件名”是否存在？ 
[ ]#判断符号，在中括号 [] 内的每个元件都需要有空白键来分隔；
if [ 条件判断式一 ]; then
#当条件判断式一成立时， 可以进行的指令工作内容；
elif [ 条件判断式二 ]; then
#当条件判断式二成立时， 可以进行的指令工作内容；
else
#当条件判断式一与二均不成立时， 可以进行的指令工作内容；
fi
exit 0

# %%
sh [-nvx] scripts.sh
#-x ： 将使用到的 script 内容显示到屏幕上， 这是很有用的参数！
